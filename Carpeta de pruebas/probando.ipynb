# %% [markdown]
# a ver si ahora puedo

# %%
print("vamos a ver si se carga este cambio")
# Out:
# vamos a ver si se carga este cambio

# %%
print("hoy voy a cocinar pizzas")
# Out:
# hoy voy a cocinar pizzas
